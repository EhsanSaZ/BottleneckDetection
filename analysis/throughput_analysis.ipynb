# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns

# %%
def cm2inch(*tupl):
    inch = 2.54
    if isinstance(tupl[0], tuple):
        return tuple(i/inch for i in tupl[0])
    else:
        return tuple(i/inch for i in tupl)

# %% [markdown]
# # Read Congestion By
# ## sender server on Sender Ost with different threads 1
# ##  clients on Sender Ost with different threads 2
# ## receiver on receiver Ost with different threads 3
# ## clients on receiver Ost with different threads 4
# ## sender on other Ost with different threads 9
# ## receiver on other Ost with different threads 10

# %%
csv_base_directory = "/Users/ehsan/Downloads/"

# %%
csv_directory = csv_base_directory + "throughputs_data/1/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# data_frames = {}
# for name in csv_files:
#     data_frames[name] = pd.read_csv(csv_directory + name, header=None)
# print(data_frames.keys())
# Out:
# ['throughout_label_read_congestion_by_sender_sender_ost_2.csv', 'throughout_label_read_congestion_by_sender_sender_ost_12.csv', 'throughout_label_read_congestion_by_sender_sender_ost_10.csv', 'throughout_label_read_congestion_by_sender_sender_ost_0.csv', 'throughout_label_read_congestion_by_sender_sender_ost_1.csv', 'throughout_label_read_congestion_by_sender_sender_ost_4.csv', 'throughout_label_read_congestion_by_sender_sender_ost_14.csv', 'throughout_label_read_congestion_by_sender_sender_ost_16.csv', 'throughout_label_read_congestion_by_sender_sender_ost_6.csv', 'throughout_label_read_congestion_by_sender_sender_ost_8.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_sender_ost_0.csv", header=None).iloc[:,2].mean()
thr_1 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_sender_ost_1.csv", header=None).iloc[:,2].mean()
thr_2 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_sender_ost_2.csv", header=None).iloc[:,2].mean()
thr_4 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_sender_ost_4.csv", header=None).iloc[:,2].mean()
thr_6 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_sender_ost_6.csv", header=None).iloc[:,2].mean()
thr_8 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_sender_ost_8.csv", header=None).iloc[:,2].mean()
thr_10 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_sender_ost_10.csv", header=None).iloc[:,2].mean()
thr_12 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_sender_ost_12.csv", header=None).iloc[:,2].mean()
thr_14 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_sender_ost_14.csv", header=None).iloc[:,2].mean()
thr_16 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_sender_ost_16.csv", header=None).iloc[:,2].mean()
read_congestion_by_sender_on_sender_ost_x = np.array([0, 1, 2, 4, 6, 8, 10, 12, 14, 16])
read_congestion_by_sender_on_sender_ost_y = np.array([thr_0, thr_1, thr_2, thr_4, thr_6, thr_8, thr_10, thr_12, thr_14, thr_16])

# %%
csv_directory = csv_base_directory + "throughputs_data/2/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_read_congestion_by_clients_on_sender_ost_10.csv', 'throughout_label_read_congestion_by_clients_on_sender_ost_2.csv', 'throughout_label_read_congestion_by_clients_on_sender_ost_0.csv', 'throughout_label_read_congestion_by_clients_on_sender_ost_12.csv', 'throughout_label_read_congestion_by_clients_on_sender_ost_1.csv', 'throughout_label_read_congestion_by_clients_on_sender_ost_16.csv', 'throughout_label_read_congestion_by_clients_on_sender_ost_4.csv', 'throughout_label_read_congestion_by_clients_on_sender_ost_6.csv', 'throughout_label_read_congestion_by_clients_on_sender_ost_14.csv', 'throughout_label_read_congestion_by_clients_on_sender_ost_8.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_sender_ost_0.csv", header=None).iloc[:,2].mean()
thr_1 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_sender_ost_1.csv", header=None).iloc[:,2].mean()
thr_2 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_sender_ost_2.csv", header=None).iloc[:,2].mean()
thr_4 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_sender_ost_4.csv", header=None).iloc[:,2].mean()
thr_6 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_sender_ost_6.csv", header=None).iloc[:,2].mean()
thr_8 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_sender_ost_8.csv", header=None).iloc[:,2].mean()
thr_10 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_sender_ost_10.csv", header=None).iloc[:,2].mean()
thr_12 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_sender_ost_12.csv", header=None).iloc[:,2].mean()
thr_14 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_sender_ost_14.csv", header=None).iloc[:,2].mean()
thr_16 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_sender_ost_16.csv", header=None).iloc[:,2].mean()
read_congestion_by_clients_on_sender_ost_x = np.array([0, 1, 2, 4, 6, 8, 10, 12, 14, 16])
read_congestion_by_clients_on_sender_ost_y = np.array([thr_0, thr_1, thr_2, thr_4, thr_6, thr_8, thr_10, thr_12, thr_14, thr_16])

# %%
csv_directory = csv_base_directory + "throughputs_data/3/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_read_congestion_by_writer_on_writer_ost_6.csv', 'throughout_label_read_congestion_by_writer_on_writer_ost_4.csv', 'throughout_label_read_congestion_by_writer_on_writer_ost_1.csv', 'throughout_label_read_congestion_by_writer_on_writer_ost_0.csv', 'throughout_label_read_congestion_by_writer_on_writer_ost_2.csv', 'throughout_label_read_congestion_by_writer_on_writer_ost_10.csv', 'throughout_label_read_congestion_by_writer_on_writer_ost_12.csv', 'throughout_label_read_congestion_by_writer_on_writer_ost_8.csv', 'throughout_label_read_congestion_by_writer_on_writer_ost_16.csv', 'throughout_label_read_congestion_by_writer_on_writer_ost_14.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_0.csv", header=None).iloc[:,2].mean()
thr_1 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_1.csv", header=None).iloc[:,2].mean()
thr_2 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_2.csv", header=None).iloc[:,2].mean()
thr_4 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_4.csv", header=None).iloc[:,2].mean()
thr_6 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_6.csv", header=None).iloc[:,2].mean()
thr_8 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_8.csv", header=None).iloc[:,2].mean()
thr_10 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_10.csv", header=None).iloc[:,2].mean()
thr_12 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_12.csv", header=None).iloc[:,2].mean()
thr_14 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_14.csv", header=None).iloc[:,2].mean()
thr_16 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_16.csv", header=None).iloc[:,2].mean()
read_congestion_by_writer_on_writer_ost_x = np.array([0, 1, 2, 4, 6, 8, 10, 12, 14, 16])
read_congestion_by_writer_on_writer_ost_y = np.array([thr_0, thr_1, thr_2, thr_4, thr_6, thr_8, thr_10, thr_12, thr_14, thr_16])

# %%
# csv_directory = "/home/esaeedizade/Desktop/throughputs_data/3_1/"
# csv_files = os.listdir(csv_directory)
# print(csv_files)
#
# thr_0 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_0.csv", header=None).iloc[:,2].mean()
# thr_1 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_1.csv", header=None).iloc[:,2].mean()
# thr_2 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_2.csv", header=None).iloc[:,2].mean()
# thr_4 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_4.csv", header=None).iloc[:,2].mean()
# thr_6 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_6.csv", header=None).iloc[:,2].mean()
# thr_8 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_8.csv", header=None).iloc[:,2].mean()
# thr_10 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_10.csv", header=None).iloc[:,2].mean()
# thr_12 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_12.csv", header=None).iloc[:,2].mean()
# thr_14 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_14.csv", header=None).iloc[:,2].mean()
# thr_16 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_writer_ost_16.csv", header=None).iloc[:,2].mean()
# read_congestion_by_writer_on_writer_ost_x_1 = np.array([0, 1, 2, 4, 6, 8, 10, 12, 14, 16])
# read_congestion_by_writer_on_writer_ost_y_1 = np.array([thr_0, thr_1, thr_2, thr_4, thr_6, thr_8, thr_10, thr_12, thr_14, thr_16])

# %%
csv_directory = csv_base_directory + "throughputs_data/4/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_read_congestion_by_clients_on_receiver_ost_8.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_10.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_12.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_16.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_14.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_2.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_1.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_0.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_4.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_6.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_0.csv", header=None).iloc[:,2].mean()
thr_1 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_1.csv", header=None).iloc[:,2].mean()
thr_2 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_2.csv", header=None).iloc[:,2].mean()
thr_4 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_4.csv", header=None).iloc[:,2].mean()
thr_6 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_6.csv", header=None).iloc[:,2].mean()
thr_8 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_8.csv", header=None).iloc[:,2].mean()
thr_10 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_10.csv", header=None).iloc[:,2].mean()
thr_12 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_12.csv", header=None).iloc[:,2].mean()
thr_14 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_14.csv", header=None).iloc[:,2].mean()
thr_16 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_16.csv", header=None).iloc[:,2].mean()
read_congestion_by_clients_on_receiver_ost_x = np.array([0, 1, 2, 4, 6, 8, 10, 12, 14, 16])
read_congestion_by_clients_on_receiver_ost_y = np.array([thr_0, thr_1, thr_2, thr_4, thr_6, thr_8, thr_10, thr_12, thr_14, thr_16])

# %%
# csv_directory = "/home/esaeedizade/Desktop/throughputs_data/4_1/"
# csv_files = os.listdir(csv_directory)
# print(csv_files)
# thr_0 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_0.csv", header=None).iloc[:,2].mean()
# thr_1 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_1.csv", header=None).iloc[:,2].mean()
# thr_2 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_2.csv", header=None).iloc[:,2].mean()
# thr_4 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_4.csv", header=None).iloc[:,2].mean()
# thr_6 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_6.csv", header=None).iloc[:,2].mean()
# thr_8 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_8.csv", header=None).iloc[:,2].mean()
# thr_10 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_10.csv", header=None).iloc[:,2].mean()
# thr_12 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_12.csv", header=None).iloc[:,2].mean()
# thr_14 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_14.csv", header=None).iloc[:,2].mean()
# thr_16 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_clients_on_receiver_ost_16.csv", header=None).iloc[:,2].mean()
# read_congestion_by_clients_on_receiver_ost_x_1 = np.array([0, 1, 2, 4, 6, 8, 10, 12, 14, 16])
# read_congestion_by_clients_on_receiver_ost_y_1 = np.array([thr_0, thr_1, thr_2, thr_4, thr_6, thr_8, thr_10, thr_12, thr_14, thr_16])
# Out:
# ['throughout_label_read_congestion_by_clients_on_receiver_ost_1.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_12.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_14.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_8.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_6.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_0.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_2.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_4.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_10.csv', 'throughout_label_read_congestion_by_clients_on_receiver_ost_16.csv']

# %%
csv_directory = csv_base_directory + "throughputs_data/9/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_read_congestion_by_sender_on_other_ost_8.csv', 'throughout_label_read_congestion_by_sender_on_other_ost_14.csv', 'throughout_label_read_congestion_by_sender_on_other_ost_16.csv', 'throughout_label_read_congestion_by_sender_on_other_ost_12.csv', 'throughout_label_read_congestion_by_sender_on_other_ost_10.csv', 'throughout_label_read_congestion_by_sender_on_other_ost_2.csv', 'throughout_label_read_congestion_by_sender_on_other_ost_0.csv', 'throughout_label_read_congestion_by_sender_on_other_ost_1.csv', 'throughout_label_read_congestion_by_sender_on_other_ost_4.csv', 'throughout_label_read_congestion_by_sender_on_other_ost_6.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_0.csv", header=None).iloc[:,2].mean()
thr_1 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_1.csv", header=None).iloc[:,2].mean()
thr_2 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_2.csv", header=None).iloc[:,2].mean()
thr_4 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_4.csv", header=None).iloc[:,2].mean()
thr_6 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_6.csv", header=None).iloc[:,2].mean()
thr_8 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_8.csv", header=None).iloc[:,2].mean()
thr_10 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_10.csv", header=None).iloc[:,2].mean()
thr_12 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_12.csv", header=None).iloc[:,2].mean()
thr_14 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_14.csv", header=None).iloc[:,2].mean()
thr_16 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_16.csv", header=None).iloc[:,2].mean()
read_congestion_by_sender_on_other_ost_x = np.array([0, 1, 2, 4, 6, 8, 10, 12, 14, 16])
read_congestion_by_sender_on_other_ost_y = np.array([thr_0, thr_1, thr_2, thr_4, thr_6, thr_8, thr_10, thr_12, thr_14, thr_16])

# %%
csv_directory = csv_base_directory + "throughputs_data/10/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_read_congestion_by_writer_on_other_ost_8.csv', '.DS_Store', 'throughout_label_read_congestion_by_writer_on_other_ost_10.csv', 'throughout_label_read_congestion_by_writer_on_other_ost_6.csv', 'throughout_label_read_congestion_by_writer_on_other_ost_4.csv', 'throughout_label_read_congestion_by_writer_on_other_ost_12.csv', 'throughout_label_read_congestion_by_writer_on_other_ost_1.csv', 'throughout_label_read_congestion_by_writer_on_other_ost_16.csv', 'throughout_label_read_congestion_by_writer_on_other_ost_0.csv', 'throughout_label_read_congestion_by_writer_on_other_ost_2.csv', 'throughout_label_read_congestion_by_writer_on_other_ost_14.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_other_ost_0.csv", header=None).iloc[:,2].mean()
thr_1 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_other_ost_1.csv", header=None).iloc[:,2].mean()
thr_2 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_other_ost_2.csv", header=None).iloc[:,2].mean()
thr_4 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_other_ost_4.csv", header=None).iloc[:,2].mean()
thr_6 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_other_ost_6.csv", header=None).iloc[:,2].mean()
thr_8 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_other_ost_8.csv", header=None).iloc[:,2].mean()
thr_10 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_other_ost_10.csv", header=None).iloc[:,2].mean()
thr_12 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_other_ost_12.csv", header=None).iloc[:,2].mean()
thr_14 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_other_ost_14.csv", header=None).iloc[:,2].mean()
thr_16 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_writer_on_other_ost_16.csv", header=None).iloc[:,2].mean()
read_congestion_by_writer_on_other_ost_x = np.array([0, 1, 2, 4, 6, 8, 10, 12, 14, 16])
read_congestion_by_writer_on_other_ost_y = np.array([thr_0, thr_1, thr_2, thr_4, thr_6, thr_8, thr_10, thr_12, thr_14, thr_16])

# %%
# csv_directory = csv_base_directory + "throughputs_data/9_1/"
# csv_files = os.listdir(csv_directory)
# print(csv_files)
# thr_0 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_0.csv", header=None).iloc[:,2].mean()
# thr_1 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_1.csv", header=None).iloc[:,2].mean()
# thr_2 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_2.csv", header=None).iloc[:,2].mean()
# thr_4 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_4.csv", header=None).iloc[:,2].mean()
# thr_6 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_6.csv", header=None).iloc[:,2].mean()
# thr_8 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_8.csv", header=None).iloc[:,2].mean()
# thr_10 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_10.csv", header=None).iloc[:,2].mean()
# thr_12 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_12.csv", header=None).iloc[:,2].mean()
# thr_14 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_14.csv", header=None).iloc[:,2].mean()
# thr_16 = pd.read_csv(csv_directory + "throughout_label_read_congestion_by_sender_on_other_ost_16.csv", header=None).iloc[:,2].mean()
# read_congestion_by_sender_on_other_ost_x_1 = np.array([0, 1, 2, 4, 6, 8, 10, 12, 14, 16])
# read_congestion_by_sender_on_other_ost_y_1 = np.array([thr_0, thr_1, thr_2, thr_4, thr_6, thr_8, thr_10, thr_12, thr_14, thr_16])

# %%
from cmath import log
from matplotlib.pyplot import figure
from matplotlib import pyplot as plt
figure(figsize=(9, 3), dpi=160)
plt.rcParams.update({'font.size': 16})

plt.yticks(np.arange(0, max(read_congestion_by_sender_on_sender_ost_y)+1, 0.25))
plt.plot(read_congestion_by_sender_on_sender_ost_x, read_congestion_by_sender_on_sender_ost_y, marker='o', label = "By sender on sender OST")
plt.plot(read_congestion_by_clients_on_sender_ost_x, read_congestion_by_clients_on_sender_ost_y, marker='o', label = "By clients on sender OST")
plt.plot(read_congestion_by_writer_on_writer_ost_x, read_congestion_by_writer_on_writer_ost_y, marker='o', label = "By receiver on receiver OST")
# plt.plot(read_congestion_by_writer_on_writer_ost_x_1, read_congestion_by_writer_on_writer_ost_y_1, label = "read_congestion_by_writer_on_writer_ost_1")
plt.plot(read_congestion_by_clients_on_receiver_ost_x, read_congestion_by_clients_on_receiver_ost_y, marker='o', label = "By clients on receiver OST")
# plt.plot(read_congestion_by_clients_on_receiver_ost_x_1, read_congestion_by_clients_on_receiver_ost_y_1, label = "read_congestion_by_clients_on_receiver_ost_1")
plt.plot(read_congestion_by_sender_on_other_ost_x, read_congestion_by_sender_on_other_ost_y, marker='o', label = "By sender on other OST")
#
# plt.plot(read_congestion_by_sender_on_other_ost_x_1, read_congestion_by_sender_on_other_ost_y_1, marker='o', label = "read_congestion_by_sender_on_other_ost_1")
#
plt.plot(read_congestion_by_writer_on_other_ost_x, read_congestion_by_writer_on_other_ost_y, marker='o', label = "By receiver on other OST")
plt.legend(fontsize=14, framealpha=0.5, loc='upper left',
           ncol=2, bbox_to_anchor=(-0.01, 1.46))
plt.xlabel('Threads number')
# plt.xticks(fontsize=14)
plt.ylabel('Throughput (Gb/s)')
# plt.yticks(fontsize=14)
# plt.title('Effect of read operation on transfer\'s throughput')
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
# plt.savefig('Effect of read operation on transfer throughput.pdf', bbox_inches='tight')
plt.show()
# plt.savefig('Effect of read operation on transfer\' throughput.png')

# %% [markdown]
# # Write Congestion By
# ## sender server on Sender Ost with different threads 5
# ## clients on Sender Ost with different threads 6
# ## receiver server on receiver Ost with different threads 7
# ## clients server on receiver Ost with different threads 8
# ## sender server on other Ost with different threads 11
# ## receiver server on other Ost with different threads 12

# %%
csv_directory = csv_base_directory + "throughputs_data/5/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_write_congestion_by_sender_on_sender_ost_8.csv', '.DS_Store', 'throughout_label_write_congestion_by_sender_on_sender_ost_10.csv', 'throughout_label_write_congestion_by_sender_on_sender_ost_12.csv', 'throughout_label_write_congestion_by_sender_on_sender_ost_16.csv', 'throughout_label_write_congestion_by_sender_on_sender_ost_14.csv', 'throughout_label_write_congestion_by_sender_on_sender_ost_2.csv', 'throughout_label_write_congestion_by_sender_on_sender_ost_1.csv', 'throughout_label_write_congestion_by_sender_on_sender_ost_0.csv', 'throughout_label_write_congestion_by_sender_on_sender_ost_4.csv', 'throughout_label_write_congestion_by_sender_on_sender_ost_6.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_sender_ost_0.csv", header=None).iloc[:,2].mean()
thr_1 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_sender_ost_1.csv", header=None).iloc[:,2].mean()
thr_2 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_sender_ost_2.csv", header=None).iloc[:,2].mean()
thr_4 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_sender_ost_4.csv", header=None).iloc[:,2].mean()
thr_6 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_sender_ost_6.csv", header=None).iloc[:,2].mean()
thr_8 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_sender_ost_8.csv", header=None).iloc[:,2].mean()
thr_10 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_sender_ost_10.csv", header=None).iloc[:,2].mean()
thr_12 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_sender_ost_12.csv", header=None).iloc[:,2].mean()
thr_14 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_sender_ost_14.csv", header=None).iloc[:,2].mean()
thr_16 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_sender_ost_16.csv", header=None).iloc[:,2].mean()
# thr_32 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_sender_ost_32.csv", header=None).iloc[:,2].mean()
# thr_64 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_sender_ost_64.csv", header=None).iloc[:,2].mean()
# thr_128 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_sender_ost_128.csv", header=None).iloc[:,2].mean()
write_congestion_by_sender_on_sender_ost_x = np.array([0, 1, 2, 4, 6, 8, 10, 12, 14, 16])
write_congestion_by_sender_on_sender_ost_y = np.array([thr_0, thr_1, thr_2, thr_4, thr_6, thr_8, thr_10, thr_12, thr_14, thr_16])

# %%
csv_directory = csv_base_directory + "throughputs_data/6/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_write_congestion_by_clients_on_sender_ost_2.csv', 'throughout_label_write_congestion_by_clients_on_sender_ost_1.csv', 'throughout_label_write_congestion_by_clients_on_sender_ost_0.csv', 'throughout_label_write_congestion_by_clients_on_sender_ost_4.csv', 'throughout_label_write_congestion_by_clients_on_sender_ost_6.csv', 'throughout_label_write_congestion_by_clients_on_sender_ost_12.csv', 'throughout_label_write_congestion_by_clients_on_sender_ost_10.csv', 'throughout_label_write_congestion_by_clients_on_sender_ost_14.csv', 'throughout_label_write_congestion_by_clients_on_sender_ost_16.csv', 'throughout_label_write_congestion_by_clients_on_sender_ost_8.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_sender_ost_0.csv", header=None).iloc[:,2].mean()
thr_1 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_sender_ost_1.csv", header=None).iloc[:,2].mean()
thr_2 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_sender_ost_2.csv", header=None).iloc[:,2].mean()
thr_4 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_sender_ost_4.csv", header=None).iloc[:,2].mean()
thr_6 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_sender_ost_6.csv", header=None).iloc[:,2].mean()
thr_8 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_sender_ost_8.csv", header=None).iloc[:,2].mean()
thr_10 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_sender_ost_10.csv", header=None).iloc[:,2].mean()
thr_12 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_sender_ost_12.csv", header=None).iloc[:,2].mean()
thr_14 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_sender_ost_14.csv", header=None).iloc[:,2].mean()
thr_16 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_sender_ost_16.csv", header=None).iloc[:,2].mean()
# thr_32 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_sender_ost_32.csv", header=None).iloc[:,2].mean()
# thr_64 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_sender_ost_64.csv", header=None).iloc[:,2].mean()
# thr_128 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_sender_ost_128.csv", header=None).iloc[:,2].mean()
write_congestion_by_clients_on_sender_ost_x = np.array([0, 1, 2, 4, 6, 8, 10, 12, 14, 16])
write_congestion_by_clients_on_sender_ost_y = np.array([thr_0, thr_1, thr_2, thr_4, thr_6, thr_8, thr_10, thr_12, thr_14, thr_16])

# %%
csv_directory = csv_base_directory + "throughputs_data/7/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_write_congestion_by_receiver_on_receiver_ost_8.csv', 'throughout_label_write_congestion_by_receiver_on_receiver_ost_10.csv', 'throughout_label_write_congestion_by_receiver_on_receiver_ost_12.csv', 'throughout_label_write_congestion_by_receiver_on_receiver_ost_16.csv', 'throughout_label_write_congestion_by_receiver_on_receiver_ost_14.csv', 'throughout_label_write_congestion_by_receiver_on_receiver_ost_1.csv', 'throughout_label_write_congestion_by_receiver_on_receiver_ost_0.csv', 'throughout_label_write_congestion_by_receiver_on_receiver_ost_2.csv', 'throughout_label_write_congestion_by_receiver_on_receiver_ost_6.csv', 'throughout_label_write_congestion_by_receiver_on_receiver_ost_4.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_receiver_ost_0.csv", header=None).iloc[:,2].mean()
thr_1 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_receiver_ost_1.csv", header=None).iloc[:,2].mean()
thr_2 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_receiver_ost_2.csv", header=None).iloc[:,2].mean()
thr_4 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_receiver_ost_4.csv", header=None).iloc[:,2].mean()
thr_6 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_receiver_ost_6.csv", header=None).iloc[:,2].mean()
thr_8 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_receiver_ost_8.csv", header=None).iloc[:,2].mean()
thr_10 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_receiver_ost_10.csv", header=None).iloc[:,2].mean()
thr_12 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_receiver_ost_12.csv", header=None).iloc[:,2].mean()
thr_14 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_receiver_ost_14.csv", header=None).iloc[:,2].mean()
thr_16 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_receiver_ost_16.csv", header=None).iloc[:,2].mean()
# thr_32 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_receiver_ost_32.csv", header=None).iloc[:,2].mean()
# thr_64 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_receiver_ost_64.csv", header=None).iloc[:,2].mean()
# thr_128 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_receiver_ost_128.csv", header=None).iloc[:,2].mean()
write_congestion_by_receiver_on_receiver_ost_x = np.array([0, 1, 2, 4, 6, 8, 10, 12, 14, 16])
write_congestion_by_receiver_on_receiver_ost_y = np.array([thr_0, thr_1, thr_2, thr_4, thr_6, thr_8, thr_10, thr_12, thr_14, thr_16])

# %%
csv_directory = csv_base_directory + "throughputs_data/8/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_write_congestion_by_clients_on_receiver_ost_14.csv', 'throughout_label_write_congestion_by_clients_on_receiver_ost_16.csv', 'throughout_label_write_congestion_by_clients_on_receiver_ost_12.csv', 'throughout_label_write_congestion_by_clients_on_receiver_ost_8.csv', 'throughout_label_write_congestion_by_clients_on_receiver_ost_10.csv', 'throughout_label_write_congestion_by_clients_on_receiver_ost_4.csv', 'throughout_label_write_congestion_by_clients_on_receiver_ost_6.csv', 'throughout_label_write_congestion_by_clients_on_receiver_ost_2.csv', 'throughout_label_write_congestion_by_clients_on_receiver_ost_0.csv', 'throughout_label_write_congestion_by_clients_on_receiver_ost_1.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_receiver_ost_0.csv", header=None).iloc[:,2].mean()
thr_1 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_receiver_ost_1.csv", header=None).iloc[:,2].mean()
thr_2 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_receiver_ost_2.csv", header=None).iloc[:,2].mean()
thr_4 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_receiver_ost_4.csv", header=None).iloc[:,2].mean()
thr_6 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_receiver_ost_6.csv", header=None).iloc[:,2].mean()
thr_8 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_receiver_ost_8.csv", header=None).iloc[:,2].mean()
thr_10 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_receiver_ost_10.csv", header=None).iloc[:,2].mean()
thr_12 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_receiver_ost_12.csv", header=None).iloc[:,2].mean()
thr_14 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_receiver_ost_14.csv", header=None).iloc[:,2].mean()
thr_16 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_receiver_ost_16.csv", header=None).iloc[:,2].mean()
# thr_32 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_receiver_ost_32.csv", header=None).iloc[:,2].mean()
# thr_64 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_receiver_ost_64.csv", header=None).iloc[:,2].mean()
# thr_128 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_clients_on_receiver_ost_128.csv", header=None).iloc[:,2].mean()
write_congestion_by_clients_on_receiver_ost_x = np.array([0, 1, 2, 4, 6, 8, 10, 12, 14, 16])
write_congestion_by_clients_on_receiver_ost_y = np.array([thr_0, thr_1, thr_2, thr_4, thr_6, thr_8, thr_10, thr_12, thr_14, thr_16])

# %%
csv_directory = csv_base_directory + "throughputs_data/11/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_write_congestion_by_sender_on_other_ost_1.csv', 'throughout_label_write_congestion_by_sender_on_other_ost_0.csv', 'throughout_label_write_congestion_by_sender_on_other_ost_2.csv', 'throughout_label_write_congestion_by_sender_on_other_ost_6.csv', 'throughout_label_write_congestion_by_sender_on_other_ost_4.csv', 'throughout_label_write_congestion_by_sender_on_other_ost_8.csv', 'throughout_label_write_congestion_by_sender_on_other_ost_14.csv', 'throughout_label_write_congestion_by_sender_on_other_ost_16.csv', 'throughout_label_write_congestion_by_sender_on_other_ost_12.csv', 'throughout_label_write_congestion_by_sender_on_other_ost_10.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_other_ost_0.csv", header=None).iloc[:,2].mean()
thr_1 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_other_ost_1.csv", header=None).iloc[:,2].mean()
thr_2 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_other_ost_2.csv", header=None).iloc[:,2].mean()
thr_4 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_other_ost_4.csv", header=None).iloc[:,2].mean()
thr_6 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_other_ost_6.csv", header=None).iloc[:,2].mean()
thr_8 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_other_ost_8.csv", header=None).iloc[:,2].mean()
thr_10 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_other_ost_10.csv", header=None).iloc[:,2].mean()
thr_12 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_other_ost_12.csv", header=None).iloc[:,2].mean()
thr_14 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_other_ost_14.csv", header=None).iloc[:,2].mean()
thr_16 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_other_ost_16.csv", header=None).iloc[:,2].mean()
# thr_32 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_other_ost_1_32.csv", header=None).iloc[:,2].mean()
# thr_64 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_other_ost_1_64.csv", header=None).iloc[:,2].mean()
# thr_128 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_sender_on_other_ost_1_128.csv", header=None).iloc[:,2].mean()
write_congestion_by_sender_on_other_ost_x = np.array([0, 1, 2, 4, 6, 8, 10, 12, 14, 16])
write_congestion_by_sender_on_other_ost_y = np.array([thr_0, thr_1, thr_2, thr_4, thr_6, thr_8, thr_10, thr_12, thr_14, thr_16])

# %%
csv_directory = csv_base_directory + "throughputs_data/12/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_write_congestion_by_receiver_on_other_ost_6.csv', 'throughout_label_write_congestion_by_receiver_on_other_ost_4.csv', 'throughout_label_write_congestion_by_receiver_on_other_ost_0.csv', 'throughout_label_write_congestion_by_receiver_on_other_ost_1.csv', 'throughout_label_write_congestion_by_receiver_on_other_ost_2.csv', 'throughout_label_write_congestion_by_receiver_on_other_ost_10.csv', 'throughout_label_write_congestion_by_receiver_on_other_ost_12.csv', 'throughout_label_write_congestion_by_receiver_on_other_ost_16.csv', 'throughout_label_write_congestion_by_receiver_on_other_ost_14.csv', 'throughout_label_write_congestion_by_receiver_on_other_ost_8.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_other_ost_0.csv", header=None).iloc[:,2].mean()
thr_1 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_other_ost_1.csv", header=None).iloc[:,2].mean()
thr_2 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_other_ost_2.csv", header=None).iloc[:,2].mean()
thr_4 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_other_ost_4.csv", header=None).iloc[:,2].mean()
thr_6 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_other_ost_6.csv", header=None).iloc[:,2].mean()
thr_8 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_other_ost_8.csv", header=None).iloc[:,2].mean()
thr_10 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_other_ost_10.csv", header=None).iloc[:,2].mean()
thr_12 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_other_ost_12.csv", header=None).iloc[:,2].mean()
thr_14 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_other_ost_14.csv", header=None).iloc[:,2].mean()
thr_16 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_other_ost_16.csv", header=None).iloc[:,2].mean()
# thr_32 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_other_ost_1_32.csv", header=None).iloc[:,2].mean()
# thr_64 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_other_ost_1_64.csv", header=None).iloc[:,2].mean()
# thr_128 = pd.read_csv(csv_directory + "throughout_label_write_congestion_by_receiver_on_other_ost_1_128.csv", header=None).iloc[:,2].mean()
write_congestion_by_receiver_on_other_ost_x = np.array([0, 1, 2, 4, 6, 8, 10, 12, 14, 16])
write_congestion_by_receiver_on_other_ost_y = np.array([thr_0, thr_1, thr_2, thr_4, thr_6, thr_8, thr_10, thr_12, thr_14, thr_16])

# %%
from matplotlib.pyplot import figure
from matplotlib import pyplot as plt
plt.rcParams.update({'font.size': 16})

figure(figsize=(9, 3), dpi=160)
plt.yticks(np.arange(0, max(write_congestion_by_sender_on_sender_ost_y)+1, 0.25))
plt.xticks(np.arange(0, 130, 2))
plt.plot(write_congestion_by_sender_on_sender_ost_x, write_congestion_by_sender_on_sender_ost_y, marker='o', label = "By sender on sender OST")
plt.plot(write_congestion_by_clients_on_sender_ost_x, write_congestion_by_clients_on_sender_ost_y, marker='o', label = "By clients on sender OST")
plt.plot(write_congestion_by_receiver_on_receiver_ost_x, write_congestion_by_receiver_on_receiver_ost_y, marker='o', label = "By receiver on receiver OST")
plt.plot(write_congestion_by_clients_on_receiver_ost_x, write_congestion_by_clients_on_receiver_ost_y, marker='o', label = "By clients on receiver OST")
plt.plot(write_congestion_by_sender_on_other_ost_x, write_congestion_by_sender_on_other_ost_y, marker='o', label = "By sender on other OST")
plt.plot(write_congestion_by_receiver_on_other_ost_x, write_congestion_by_receiver_on_other_ost_y, marker='o', label = "By receiver on other OST")

plt.legend(fontsize=14, framealpha=0.5, loc='upper left',
           ncol=2, bbox_to_anchor=(-0.01, 1.46))
plt.xlabel('Threads number')
# plt.xticks(fontsize=14)
plt.ylabel('Throughput (Gb/s)')
# plt.yticks(fontsize=14)
# plt.title('Effect of write operation on transfer\'s throughput')
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
# plt.savefig('Effect of write operation on transfer\'s throughput.pdf', bbox_inches='tight')
plt.show()
# fig.savefig("write_1KB.jpg", bbox_inches='tight')

# %%
from matplotlib.pyplot import figure
from matplotlib import pyplot as plt
plt.rcParams.update({'font.size': 16})

figure(figsize=(9, 3), dpi=160)
plt.yticks(np.arange(0, 1.5, 0.25))
plt.xticks(np.arange(0, 130, 2))

plt.plot(read_congestion_by_clients_on_sender_ost_x, read_congestion_by_clients_on_sender_ost_y, marker='x', label = "Read Congestion On Sender OST")
# plt.plot(read_congestion_by_writer_on_writer_ost_x, read_congestion_by_writer_on_writer_ost_y, marker='d', label = "Read Congestion On Receiver OST")
plt.plot(read_congestion_by_clients_on_receiver_ost_x, read_congestion_by_clients_on_receiver_ost_y, marker='d', label = "Read Congestion On Receiver OST")

plt.plot(write_congestion_by_clients_on_sender_ost_x, write_congestion_by_clients_on_sender_ost_y, marker='o', label = "Write Congestion On Sender OST")
plt.plot(write_congestion_by_clients_on_receiver_ost_x, write_congestion_by_clients_on_receiver_ost_y, marker='v', label = "Write Congestion On Receiver OST")

plt.legend(fontsize=14, framealpha=0.5, loc='upper left',
           ncol=1, bbox_to_anchor=(0.2, 1.6))
plt.ylim(ymin=0)
plt.xlabel('Congestion Level( # Of Threads)')
# plt.xticks(fontsize=14)
plt.ylabel('Throughput (Gb/s)')
# plt.yticks(fontsize=14)
# plt.title('Effect of write operation on transfer\'s throughput')
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.savefig('Effect of read write operation on transfer\'s throughput.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Network Anomaly
# ## loss with different rates 14

# %%
csv_directory = csv_base_directory + "throughputs_data/14/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_network_anomaly_network_loss_0.05.csv', 'throughout_label_network_anomaly_network_loss_0.5.csv', 'throughout_label_network_anomaly_network_loss_0.1.csv', 'throughout_label_network_anomaly_network_loss_1.csv', 'throughout_label_network_anomaly_network_loss_0.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_loss_0.csv", header=None).iloc[:,2].mean()
thr_005 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_loss_0.05.csv", header=None).iloc[:,2].mean()
thr_01 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_loss_0.1.csv", header=None).iloc[:,2].mean()
thr_05 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_loss_0.5.csv", header=None).iloc[:,2].mean()
thr_1 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_loss_1.csv", header=None).iloc[:,2].mean()
network_anomaly_network_loss_x = np.array([0, 0.05, 0.1, 0.5, 1])
network_anomaly_network_loss_y = np.array([thr_0, thr_005, thr_01, thr_05, thr_1])

# %%
csv_directory = csv_base_directory + "throughputs_data/15/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_network_anomaly_network_delay_0.5.csv', 'throughout_label_network_anomaly_network_delay_0.1.csv', 'throughout_label_network_anomaly_network_delay_2.csv', 'throughout_label_network_anomaly_network_delay_1.csv', 'throughout_label_network_anomaly_network_delay_0.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_delay_0.csv", header=None).iloc[:,2].mean()
thr_01 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_delay_0.1.csv", header=None).iloc[:,2].mean()
thr_05 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_delay_0.5.csv", header=None).iloc[:,2].mean()
thr_1 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_delay_1.csv", header=None).iloc[:,2].mean()
thr_2 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_delay_2.csv", header=None).iloc[:,2].mean()
network_anomaly_network_delay_x = np.array([0, 0.1, 0.5, 1, 2])
network_anomaly_network_delay_y = np.array([thr_0, thr_01, thr_05, thr_1, thr_2])

# %%
csv_directory = csv_base_directory + "throughputs_data/16_1/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_network_anomaly_network_duplicate_10.csv', 'throughout_label_network_anomaly_network_duplicate_0.csv', '.DS_Store', 'throughout_label_network_anomaly_network_duplicate_15.csv', 'throughout_label_network_anomaly_network_duplicate_65.csv', 'throughout_label_network_anomaly_network_duplicate_60.csv', 'throughout_label_network_anomaly_network_duplicate_50.csv', 'throughout_label_network_anomaly_network_duplicate_45.csv', 'throughout_label_network_anomaly_network_duplicate_55.csv', 'throughout_label_network_anomaly_network_duplicate_40.csv', 'throughout_label_network_anomaly_network_duplicate_30.csv', 'throughout_label_network_anomaly_network_duplicate_25.csv', 'throughout_label_network_anomaly_network_duplicate_35.csv', 'throughout_label_network_anomaly_network_duplicate_20.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_duplicate_0.csv", header=None).iloc[:,2].mean()
thr_10 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_duplicate_10.csv", header=None).iloc[:,2].mean()
thr_15 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_duplicate_15.csv", header=None).iloc[:,2].mean()
thr_20 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_duplicate_20.csv", header=None).iloc[:,2].mean()
thr_25 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_duplicate_25.csv", header=None).iloc[:,2].mean()
thr_30 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_duplicate_30.csv", header=None).iloc[:,2].mean()
thr_35 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_duplicate_35.csv", header=None).iloc[:,2].mean()
thr_40 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_duplicate_40.csv", header=None).iloc[:,2].mean()
thr_45 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_duplicate_45.csv", header=None).iloc[:,2].mean()
thr_50 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_duplicate_50.csv", header=None).iloc[:,2].mean()
thr_55 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_duplicate_55.csv", header=None).iloc[:,2].mean()
thr_60 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_duplicate_60.csv", header=None).iloc[:,2].mean()
thr_65 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_duplicate_65.csv", header=None).iloc[:,2].mean()
network_anomaly_network_duplicate_x = np.array([0, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65])
network_anomaly_network_duplicate_y = np.array([thr_0, thr_10, thr_15, thr_20, thr_25, thr_30, thr_35,
                                              thr_40, thr_45, thr_50, thr_55, thr_60, thr_65])
# print(network_anomaly_network_duplicate_y)

# %%
csv_directory = csv_base_directory + "throughputs_data/17/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_network_anomaly_network_corrupt_0.5.csv', 'throughout_label_network_anomaly_network_corrupt_0.05.csv', '.DS_Store', 'throughout_label_network_anomaly_network_corrupt_0.1.csv', 'throughout_label_network_anomaly_network_corrupt_0.csv', 'throughout_label_network_anomaly_network_corrupt_1.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_corrupt_0.csv", header=None).iloc[:,2].mean()
thr_005 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_corrupt_0.05.csv", header=None).iloc[:,2].mean()
thr_01 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_corrupt_0.1.csv", header=None).iloc[:,2].mean()
thr_05 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_corrupt_0.5.csv", header=None).iloc[:,2].mean()
thr_1 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_corrupt_1.csv", header=None).iloc[:,2].mean()
network_anomaly_network_corrupt_x = np.array([0, 0.05, 0.1, 0.5, 1])
network_anomaly_network_corrupt_y = np.array([thr_0, thr_005, thr_01, thr_05, thr_1])

# %%
csv_directory = csv_base_directory + "throughputs_data/18_1/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_network_anomaly_network_reorder_20.csv', 'throughout_label_network_anomaly_network_reorder_35.csv', '.DS_Store', 'throughout_label_network_anomaly_network_reorder_25.csv', 'throughout_label_network_anomaly_network_reorder_30.csv', 'throughout_label_network_anomaly_network_reorder_0.csv', 'throughout_label_network_anomaly_network_reorder_40.csv', 'throughout_label_network_anomaly_network_reorder_55.csv', 'throughout_label_network_anomaly_network_reorder_45.csv', 'throughout_label_network_anomaly_network_reorder_50.csv', 'throughout_label_network_anomaly_network_reorder_60.csv', 'throughout_label_network_anomaly_network_reorder_65.csv', 'throughout_label_network_anomaly_network_reorder_15.csv', 'throughout_label_network_anomaly_network_reorder_10.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_reorder_0.csv", header=None).iloc[:,2].mean()
thr_10 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_reorder_10.csv", header=None).iloc[:,2].mean()
thr_15 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_reorder_15.csv", header=None).iloc[:,2].mean()
thr_20 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_reorder_20.csv", header=None).iloc[:,2].mean()
thr_25 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_reorder_25.csv", header=None).iloc[:,2].mean()
thr_30 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_reorder_30.csv", header=None).iloc[:,2].mean()
thr_35 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_reorder_35.csv", header=None).iloc[:,2].mean()
thr_40 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_reorder_40.csv", header=None).iloc[:,2].mean()
thr_45 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_reorder_45.csv", header=None).iloc[:,2].mean()
thr_50 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_reorder_50.csv", header=None).iloc[:,2].mean()
thr_55 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_reorder_55.csv", header=None).iloc[:,2].mean()
thr_60 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_reorder_60.csv", header=None).iloc[:,2].mean()
thr_65 = pd.read_csv(csv_directory + "throughout_label_network_anomaly_network_reorder_65.csv", header=None).iloc[:,2].mean()
network_anomaly_network_reorder_x = np.array([0, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65])
network_anomaly_network_reorder_y = np.array([thr_0, thr_10, thr_15, thr_20, thr_25, thr_30, thr_35,
                                              thr_40, thr_45, thr_50, thr_55, thr_60, thr_65])
# print(network_anomaly_network_duplicate_y)

# %%
csv_directory = csv_base_directory + "throughputs_data/21/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['dataset_159.csv', 'dataset_158.csv', 'dataset_160.csv', 'dataset_0.csv', 'dataset_157.csv']

# %%
thr_0 = pd.read_csv(csv_directory + "dataset_0.csv", header=None).iloc[:,2].mean()
thr_5 = pd.read_csv(csv_directory + "dataset_157.csv", header=None).iloc[:,2].mean()
thr_10 = pd.read_csv(csv_directory + "dataset_158.csv", header=None).iloc[:,2].mean()
thr_15 = pd.read_csv(csv_directory + "dataset_159.csv", header=None).iloc[:,2].mean()
thr_20 = pd.read_csv(csv_directory + "dataset_160.csv", header=None).iloc[:,2].mean()

network_anomaly_network_congestion_x = np.array([0, 5, 10, 15, 20])
network_anomaly_network_congestion_y = np.array([thr_0,thr_5, thr_10, thr_15, thr_20])

# %%
cm2inch(8,3.5)
# Out:
# (3.149606299212598, 1.3779527559055118)

# %%
from matplotlib import pyplot as plt
plt.rcParams.update({'font.size': 16})
fig, ax = plt.subplots(figsize =(9,3), dpi=160)
severity_levels = np.arange(5) + 1
ax.plot(severity_levels, network_anomaly_network_loss_y, marker='x', label = "Network packet loss", linewidth=3)
ax.plot(severity_levels, network_anomaly_network_delay_y, marker='d', label = "Network packet delay", linewidth=3)
ax.plot(severity_levels, network_anomaly_network_corrupt_y, marker='o', label = "Network packet corrupt", linewidth=3)
ax.plot(severity_levels, network_anomaly_network_congestion_y, marker='v', label = "Network congestion", linewidth=3)
ax.grid(True, axis='y', linestyle='--', alpha=0.5 )
ax.set_xlabel('Severity Levels')
ax.set_xticks(np.arange(1,6,1))
ax.set_ylabel('Throughput (Gb/s)')
ax.set_yticks(np.arange(0,1.50,0.20))
plt.legend(fontsize = 14, loc='lower left')
plt.savefig("effect of network_bottlenecks_1_4.pdf", bbox_inches='tight')

fig2, ax2 = plt.subplots(figsize =(9,3), dpi=160)
severity_levels = np.arange(13)+1
ax2.plot(severity_levels, network_anomaly_network_reorder_y, marker='o', label = "Network packet reorder", linewidth=3)
ax2.plot(severity_levels, network_anomaly_network_duplicate_y, marker='x', label = "Network packet duplicate", linewidth=3)

ax2.grid(True, axis='y', linestyle='--', alpha=0.5 )
ax2.set_xlabel('Severity Levels')
ax2.set_xticks(np.arange(1,14,1))
ax2.set_ylabel('Throughput (Gb/s)')
ax2.set_yticks(np.arange(0,1.50,0.20))
plt.legend(fontsize = 14, loc='lower left')
plt.savefig("effect of network_bottlenecks_5_6.pdf", bbox_inches='tight')

# %%
from matplotlib.pyplot import figure
from matplotlib import pyplot as plt
plt.rcParams.update({'font.size': 20})

# fig = figure(figsize=(30, 11), dpi=160)
# plt.yticks(np.arange(0, max(write_congestion_by_sender_on_sender_ost_y)+1, 0.1))
fig, ax = plt.subplots(figsize =(10, 3.5), dpi=160)
# ax = fig.add_subplot(231)
ax.plot(network_anomaly_network_loss_x, network_anomaly_network_loss_y, marker='o', label = "Effect of network packet loss on throughput")
ax.set_title('Packet loss')
ax.grid(True, axis='y', linestyle='--', alpha=0.5 )
ax.set_xlabel('Loss percentage')
ax.set_xticks(np.arange(0,1.1,0.1))
ax.set_ylabel('Throughput (Gb/s)')
ax.set_yticks(np.arange(0,1.50,0.20))
plt.savefig("effect of network anomalies packet loss on transfer throughput.jpg", bbox_inches='tight')

fig2, ax2 = plt.subplots(figsize =(10, 3.5), dpi=160)
# ax2 = fig.add_subplot(232)
ax2.plot(network_anomaly_network_delay_x, network_anomaly_network_delay_y, marker='o', label = "network_anomaly_network_delay")
ax2.set_title('Packet delay')
ax2.grid(True, axis='y', linestyle='--', alpha=0.5 )
ax2.set_xlabel('Delay (ms)')
ax2.set_xticks(np.arange(0,2.2,0.2))
ax2.set_ylabel('Throughput (Gb/s)')
ax2.set_yticks(np.arange(0,1.50,0.2))
plt.savefig("effect of network anomalies packet delay on transfer throughput.jpg", bbox_inches='tight')

fig3, ax3 = plt.subplots(figsize =(10, 3.5), dpi=160)
# ax3 = fig.add_subplot(233)
ax3.plot(network_anomaly_network_corrupt_x, network_anomaly_network_corrupt_y, marker='o', label = "Effect of network packet corrupt on throughput")
ax3.set_title('Packet corrupt')
ax3.grid(True, axis='y', linestyle='--', alpha=0.5 )
ax3.set_xlabel('Corrupt percentage')
ax3.set_xticks(np.arange(0,1.1,0.1))
ax3.set_ylabel('Throughput (Gb/s)')
ax3.set_yticks(np.arange(1.1,1.45,0.05))
plt.savefig("effect of network anomalies packet corrupt on transfer throughput.jpg", bbox_inches='tight')

fig4, ax4 = plt.subplots(figsize =(10, 3.5), dpi=160)
# ax4 = fig.add_subplot(234)
ax4.plot(network_anomaly_network_reorder_x, network_anomaly_network_reorder_y, marker='o', label = "Effect of network packet reorder on throughput")
ax4.set_title('Packet reorder')
ax4.grid(True, axis='y', linestyle='--', alpha=0.5 )
ax4.set_xlabel('Reorder percentage')
ax4.set_xticks(np.arange(0,75,5))
ax4.set_ylabel('Throughput (Gb/s)')
ax4.set_yticks(np.arange(0.8,1.45,0.1))
plt.savefig("effect of network anomalies packet reorder on transfer throughput.jpg", bbox_inches='tight')


# THIS SEEMS THAT HAS NO IMPORTANT EFFECT !!
fig5, ax5 = plt.subplots(figsize =(10, 3.5), dpi=160)
# ax5 = fig.add_subplot(235)
ax5.plot(network_anomaly_network_duplicate_x, network_anomaly_network_duplicate_y, marker='o', label = "Effect of network packet duplicate on throughput")
ax5.set_title('Packet duplicate')
ax5.grid(True, axis='y', linestyle='--', alpha=0.5 )
ax5.set_xlabel('Duplicate percentage')
ax5.set_xticks(np.arange(0,75,5))
ax5.set_ylabel('Throughput (Gb/s)')
ax5.set_yticks(np.arange(1.1,1.45,0.1))
plt.savefig("effect of network anomalies packet duplicate on transfer throughput.jpg", bbox_inches='tight')


fig6, ax6 = plt.subplots(figsize =(10, 3.5), dpi=160)
# ax6 = fig.add_subplot(236)
ax6.plot(network_anomaly_network_congestion_x, network_anomaly_network_congestion_y, marker='o', label = "Effect of network congestion on throughput")
ax6.set_title('Network congestion')
ax6.grid(True, axis='y', linestyle='--', alpha=0.5 )
ax6.set_xlabel('Number of Iperf3 flows', )
ax6.set_ylabel('Throughput (Gb/s)')
ax6.set_yticks(np.arange(0,1.4,0.3))
plt.savefig("effect of network congestion on transfer throughput.jpg", bbox_inches='tight')

# plt.subplots_adjust(left=0.1,bottom=0.1,  right=0.9,  top=0.9,  wspace=0.2,  hspace=0.35)
#
# plt.savefig("effect of network anomalies on transfer throughput.jpg", )
# plt.show()

# %%
csv_directory = csv_base_directory + "throughputs_data/19/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_sys_config_tcp_send_buffer_4096.csv', 'throughout_label_sys_config_tcp_send_buffer_786432.csv', 'throughout_label_sys_config_tcp_send_buffer_8192.csv', 'throughout_label_sys_config_tcp_send_buffer_3145728.csv', 'throughout_label_sys_config_tcp_send_buffer_1572864.csv', 'throughout_label_sys_config_tcp_send_buffer_2048.csv', 'throughout_label_sys_config_tcp_send_buffer_1.csv']

# %%
# thr_1 = pd.read_csv(csv_directory + "throughout_label_sys_config_tcp_send_buffer_1.csv", header=None).iloc[:,2].mean()
#
# thr_05d = pd.read_csv(csv_directory + "throughout_label_sys_config_tcp_send_buffer_8192.csv", header=None).iloc[:,2].mean()
# thr_025d = pd.read_csv(csv_directory + "throughout_label_sys_config_tcp_send_buffer_4096.csv", header=None).iloc[:,2].mean()
# thr_0125d = pd.read_csv(csv_directory + "throughout_label_sys_config_tcp_send_buffer_2048.csv", header=None).iloc[:,2].mean()
#
# thr_05m= pd.read_csv(csv_directory + "throughout_label_sys_config_tcp_send_buffer_3145728.csv", header=None).iloc[:,2].mean()
# thr_025m = pd.read_csv(csv_directory + "throughout_label_sys_config_tcp_send_buffer_1572864.csv", header=None).iloc[:,2].mean()
# thr_0125m = pd.read_csv(csv_directory + "throughout_label_sys_config_tcp_send_buffer_786432.csv", header=None).iloc[:,2].mean()
# data_send_buffer = [[thr_1, thr_05d, thr_025d, thr_0125d],
#                     [thr_1, thr_05m, thr_025m, thr_0125m]]
emulab_hdd_unmerged = pd.read_csv("../prototype/emulab_d460_10Gbps_hdd_unmerged_V2.csv")
thr_1 = emulab_hdd_unmerged[emulab_hdd_unmerged.label_value ==0]['through_put'].mean()
thr_05m = emulab_hdd_unmerged[emulab_hdd_unmerged.label_value ==145]['through_put'].mean()
thr_025m = emulab_hdd_unmerged[emulab_hdd_unmerged.label_value ==146]['through_put'].mean()
thr_0125m = emulab_hdd_unmerged[emulab_hdd_unmerged.label_value ==147]['through_put'].mean()
thr_05d = emulab_hdd_unmerged[emulab_hdd_unmerged.label_value ==148]['through_put'].mean()
thr_025d = emulab_hdd_unmerged[emulab_hdd_unmerged.label_value ==149]['through_put'].mean()
thr_0125d = emulab_hdd_unmerged[emulab_hdd_unmerged.label_value ==150]['through_put'].mean()
data_send_buffer = [thr_1, thr_05m, thr_025m, thr_0125m, thr_05d, thr_025d, thr_0125d]

# %%
data_send_buffer
# Out:
# [1.2821107645750989,
#  1.2742525376234537,
#  1.2701046154612587,
#  1.2652740203233128,
#  1.274117770139128,
#  1.2446599298832464,
#  0.6499697467074891]

# %%
csv_directory = csv_base_directory + "throughputs_data/20/"
csv_files = os.listdir(csv_directory)
print(csv_files)
# Out:
# ['throughout_label_sys_config_tcp_receive_buffer_1572864.csv', 'throughout_label_sys_config_tcp_receive_buffer_3145728.csv', '.DS_Store', 'throughout_label_sys_config_tcp_receive_buffer_4096.csv', 'throughout_label_sys_config_tcp_receive_buffer_8192.csv', 'throughout_label_sys_config_tcp_receive_buffer_786432.csv', 'throughout_label_sys_config_tcp_receive_buffer_2048.csv', 'throughout_label_sys_config_tcp_receive_buffer_1.csv']

# %%
# thr_1 = pd.read_csv(csv_directory + "throughout_label_sys_config_tcp_receive_buffer_1.csv", header=None).iloc[:,2].mean()
#
# thr_05d = pd.read_csv(csv_directory + "throughout_label_sys_config_tcp_receive_buffer_8192.csv", header=None).iloc[:,2].mean()
# thr_025d = pd.read_csv(csv_directory + "throughout_label_sys_config_tcp_receive_buffer_4096.csv", header=None).iloc[:,2].mean()
# thr_0125d = pd.read_csv(csv_directory + "throughout_label_sys_config_tcp_receive_buffer_2048.csv", header=None).iloc[:,2].mean()
#
# thr_05m= pd.read_csv(csv_directory + "throughout_label_sys_config_tcp_receive_buffer_3145728.csv", header=None).iloc[:,2].mean()
# thr_025m = pd.read_csv(csv_directory + "throughout_label_sys_config_tcp_receive_buffer_1572864.csv", header=None).iloc[:,2].mean()
# thr_0125m = pd.read_csv(csv_directory + "throughout_label_sys_config_tcp_receive_buffer_786432.csv", header=None).iloc[:,2].mean()
# data_receive_buffer = [[thr_1, thr_05d, thr_025d, thr_0125d],
#                     [thr_1, thr_05m, thr_025m, thr_0125m]]
emulab_hdd_unmerged = pd.read_csv("../prototype/emulab_d460_10Gbps_hdd_unmerged_V2.csv")
thr_1 = emulab_hdd_unmerged[emulab_hdd_unmerged.label_value ==0]['through_put'].mean()
thr_05m = emulab_hdd_unmerged[emulab_hdd_unmerged.label_value ==151]['through_put'].mean()
thr_025m = emulab_hdd_unmerged[emulab_hdd_unmerged.label_value ==152]['through_put'].mean()
thr_0125m = emulab_hdd_unmerged[emulab_hdd_unmerged.label_value ==153]['through_put'].mean()
thr_05d = emulab_hdd_unmerged[emulab_hdd_unmerged.label_value ==154]['through_put'].mean()
thr_025d = emulab_hdd_unmerged[emulab_hdd_unmerged.label_value ==155]['through_put'].mean()
thr_0125d = emulab_hdd_unmerged[emulab_hdd_unmerged.label_value ==156]['through_put'].mean()
data_receive_buffer = [thr_1, thr_05m, thr_025m, thr_0125m, thr_05d, thr_025d, thr_0125d ]

# %%
data_receive_buffer
# Out:
# [1.2821107645750989,
#  1.2667714226990938,
#  1.26904029189609,
#  1.2599266901260286,
#  0.35834438060269214,
#  0.2519917192349907,
#  4.199067902655608e-05]

# %%
# # fig, ax = plt.subplots(2, 1, figsize=(12, 10), dpi=160)
# plt.rcParams.update({'font.size': 20})
# # fig.tight_layout(pad=6)
# ind = np.arange(7)
# width = 0.2
# fig, ax = plt.subplots(figsize =(13, 3.5), dpi=160)
# ax.bar(ind + 0.1, np.concatenate((data_send_buffer[1][0:1], np.zeros(6))), width, label='', color='black')
# ax.bar(ind + 0.1,np.concatenate((np.zeros(1), data_send_buffer[1][1:], np.zeros(3))), width,label='', color='green')
# ax.bar(ind+ 0.1, np.concatenate((np.zeros(4), data_send_buffer[0][1:],)) , width, label='', color='yellow')
# ax.set_ylabel('Throughput (Gb/s)')
# ax.set_xlabel('TCP Send buffer max size (bytes)')
# ax.set_title('Effect of TCP send buffer max value on throughput')
# ax.set_xticks(ticks=(ind + width / 2), labels=('6291456', '3145728', '1572864', '786432', '8192', '4096', '2048'))
# ax.grid(True, axis='y', linestyle='--', alpha=0.5 )
# ax.set_yticks(np.arange(0,1.45,0.3))
# plt.savefig("effect of TCP send buffer on transfer throughput.jpg", bbox_inches='tight')
#
# # ax[0].legend(bbox_to_anchor=(1.03, -0.12), loc='upper right')
#
# fig2, ax2 = plt.subplots(figsize =(13, 3.5), dpi=160)
#
# ax2.bar(ind + 0.1, np.concatenate((data_receive_buffer[1][0:1], np.zeros(6))), width, label='', color='black')
# ax2.bar(ind + 0.1,np.concatenate((np.zeros(1), data_receive_buffer[1][1:], np.zeros(3))), width,label='', color='green')
# ax2.bar(ind+ 0.1, np.concatenate((np.zeros(4), data_receive_buffer[0][1:],)) , width, label='', color='yellow')
# ax2.set_ylabel('Throughput (Gb/s)')
# ax2.set_xlabel('TCP receive buffer max size (bytes)')
# ax2.set_title('Effect of TCP receive buffer max value on throughput')
# ax2.set_xticks(ticks=(ind + width / 2), labels=('6291456', '3145728', '1572864', '786432', '8192', '4096', '2048'))
# ax2.grid(True, axis='y', linestyle='--', alpha=0.5 )
# ax2.set_yticks(np.arange(0,1.45,0.3))
#
# plt.savefig("effect of TCP receive buffer on transfer throughput.jpg", bbox_inches='tight')
#
# # ax[1].legend(bbox_to_anchor=(1.03, -0.12), loc='upper right')
# plt.subplots_adjust(hspace=0.3)
#
# # plt.savefig("Effect of tcp buffer value on throughput.jpg")
# # plt.show()

from matplotlib import pyplot as plt

plt.rcParams.update({'font.size': 16})
barWidth = 0.2
br1 = np.arange(7)
br2 = [x + barWidth for x in br1]

fig, ax = plt.subplots(figsize =(9, 3), dpi=160)

ax.bar(br1, data_send_buffer, barWidth, label='TCP send buffer max value', )
ax.bar(br2, data_receive_buffer, barWidth, label='TCP receive buffer max value', )

ax.set_ylabel('Throughput (Gb/s)')
ax.set_xlabel('TCP Send/Receive buffer max size (bytes)')
x_ticks_labels = ('6291456', '3145728', '1572864', '786432', '8192', '4096', '2048')
ax.set_xticks(ticks=(br1 + barWidth / 2), labels=x_ticks_labels, rotation=10)
ax.grid(True, axis='y', linestyle='--', alpha=0.5 )
ax.set_yticks(np.arange(0,1.45,0.2))
plt.legend(fontsize = 14, loc='lower left')
plt.savefig("tcp_buffer_value_effect.pdf", bbox_inches='tight')

# %%
line_0_y = pd.read_csv(csv_base_directory + "throughputs_data/1/" + "throughout_label_read_congestion_by_sender_sender_ost_0.csv", header=None).iloc[:30,2]
line_1_y =pd.read_csv(csv_base_directory + "throughputs_data/1/" + "throughout_label_read_congestion_by_sender_sender_ost_16.csv", header=None).iloc[:30,2]
line_2_y =pd.read_csv(csv_base_directory + "throughputs_data/2/" + "throughout_label_read_congestion_by_clients_on_sender_ost_16.csv", header=None).iloc[:30, 2]
line_3_y =pd.read_csv(csv_base_directory + "throughputs_data/3/" + "throughout_label_read_congestion_by_writer_on_writer_ost_16.csv", header=None).iloc[:30, 2]
line_4_y =pd.read_csv(csv_base_directory + "throughputs_data/4/" + "throughout_label_read_congestion_by_clients_on_receiver_ost_16.csv", header=None).iloc[:30, 2]
line_5_y =pd.read_csv(csv_base_directory + "throughputs_data/9/" + "throughout_label_read_congestion_by_sender_on_other_ost_16.csv", header=None).iloc[:30, 2]
line_6_y =pd.read_csv(csv_base_directory + "throughputs_data/10/" + "throughout_label_read_congestion_by_writer_on_other_ost_16.csv", header=None).iloc[:30, 2]
line_7_y =pd.read_csv(csv_base_directory + "throughputs_data/5/" + "throughout_label_write_congestion_by_sender_on_sender_ost_16.csv", header=None).iloc[:30, 2]
line_8_y =pd.read_csv(csv_base_directory + "throughputs_data/6/" + "throughout_label_write_congestion_by_clients_on_sender_ost_16.csv", header=None).iloc[:30, 2]
line_9_y =pd.read_csv(csv_base_directory + "throughputs_data/7/" + "throughout_label_write_congestion_by_receiver_on_receiver_ost_16.csv", header=None).iloc[:30, 2]
line_10_y =pd.read_csv(csv_base_directory + "throughputs_data/8/" + "throughout_label_write_congestion_by_clients_on_receiver_ost_16.csv", header=None).iloc[:30, 2]
line_11_y =pd.read_csv(csv_base_directory + "throughputs_data/11/" + "throughout_label_write_congestion_by_sender_on_other_ost_16.csv", header=None).iloc[:30, 2]
line_12_y =pd.read_csv(csv_base_directory + "throughputs_data/12/" + "throughout_label_write_congestion_by_receiver_on_other_ost_16.csv", header=None).iloc[:30, 2]
line_13_y =pd.read_csv(csv_base_directory + "throughputs_data/14/" + "throughout_label_network_anomaly_network_loss_1.csv", header=None).iloc[:30, 2]
line_14_y =pd.read_csv(csv_base_directory + "throughputs_data/15/" + "throughout_label_network_anomaly_network_delay_2.csv", header=None).iloc[:30, 2]
line_15_y =pd.read_csv(csv_base_directory + "throughputs_data/16_1/" + "throughout_label_network_anomaly_network_duplicate_65.csv", header=None).iloc[:30, 2]
line_16_y =pd.read_csv(csv_base_directory + "throughputs_data/17/" + "throughout_label_network_anomaly_network_corrupt_1.csv", header=None).iloc[:30, 2]
line_17_y =pd.read_csv(csv_base_directory + "throughputs_data/18_1/" + "throughout_label_network_anomaly_network_reorder_65.csv", header=None).iloc[:30, 2]
line_18_y =pd.read_csv(csv_base_directory + "throughputs_data/19/" + "throughout_label_sys_config_tcp_send_buffer_2048.csv", header=None).iloc[:30, 2]
line_19_y =pd.read_csv(csv_base_directory + "throughputs_data/20/" + "throughout_label_sys_config_tcp_receive_buffer_2048.csv", header=None).iloc[:30, 2]
lines = [line_0_y, line_1_y, line_2_y, line_3_y, line_4_y, line_5_y, line_6_y,
     line_7_y, line_8_y, line_9_y, line_10_y, line_11_y, line_12_y, line_13_y,
     line_14_y, line_15_y, line_16_y, line_17_y, line_18_y, line_19_y]

# %%
import numpy as np
import matplotlib.pyplot as plt

def uniqueish_color():
    """There're better ways to generate unique colors, but this isn't awful."""
    return plt.cm.gist_ncar(np.random.random())

def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

fig, ax = plt.subplots(figsize=(12, 5), dpi=160)
x = []
y = []

for  i, line in enumerate(lines):
    x = np.concatenate((x, np.arange(1,31,1) + (i * len(line))))
    y = np.concatenate((y, line))

ax.plot(x, y,linewidth=1 )
ax.set_ylabel('Throughput Gbps', fontsize=12)
ax.set_xlabel('Time seconds', fontsize=12)
ax.set_title('Throughout in different bottleneck types', fontsize=16)
ax.set_xticks(np.arange(0,601,30))
ax.xaxis.grid()
# for i, line in enumerate(lines):
#     x = np.arange(1,31,1) + (i * len(line))
#     ax.plot(x, line)
    # x = np.arange(1,2,1) + (i )
    # print(x)
    # print(line)
    # area = ( (np.var(line)+0.01) * 100 ) **2 #np.var(line)
    # ax.scatter(x, np.mean(line), s=area, color=uniqueish_color(), linewidths=0.1, )
# plt.savefig("Throughout in different bottleneck types.jpg")
# plt.show()

# %%
import glob

with open("values-16.csv", "w") as f:
    f.write("throughput\n")
    for i,val in enumerate(sorted(glob.glob("/Users/ehsan/Downloads/throughputs_data/long_transfer/inst-throughput-cc-16*"))):
        with open(val, "r") as ff:
            for line in ff.readlines():
                f.write(line.split()[-1] + "\n")

# %%
from matplotlib import pyplot as plt
plt.rcParams.update({'font.size': 16})

df = pd.read_csv("values-8.csv")
df = df[df.throughput>0]
df.throughput = df.throughput/1000
n = 300
df = df.rolling(n).mean()

# ax = df.throughput.plot(lw=3)
# plt.xlabel("Time (Seconds)", fontsize=35, labelpad=12)
# plt.ylabel("Throughput (Gbps)", fontsize=35, labelpad=12);
# ax.tick_params(axis='both', which='major', pad=12)
# ax.tick_params(axis='y', which='major', labelsize=30)
# ax.tick_params(axis='x', which='major', labelsize=30)
# plt.ylim(10, 21)
# plt.ylim(75,100)

fig, ax = plt.subplots(figsize =(9,3), dpi=160)
ax.plot(np.arange(len(df.throughput)), df.throughput, linewidth=1)
# severity_levels = np.arange(5) + 1
ax.grid(True, axis='y', linestyle='--', alpha=0.5 )
ax.set_xlabel('Time (Seconds)')
# ax.set_xticks(np.arange(1,6,1))
ax.set_ylabel('Throughput (Gb/s)')
# ax.set_yticks(np.arange(4,12,2))
# plt.legend(fontsize = 14, loc='lower left')
plt.savefig('throughput-cc8.pdf', bbox_inches='tight')

# %%
from matplotlib import pyplot as plt
plt.rcParams.update({'font.size': 16})

df = pd.read_csv("values-16.csv")
df = df[df.throughput>0]
df.throughput = df.throughput/1000
n = 300
df = df.rolling(n).mean()

# sns.set_style("whitegrid")
# plt.rcParams["figure.figsize"] = (12, 6)
# ax = df.throughput.plot(lw=3)
# plt.xlabel("Time (Seconds)", fontsize=35, labelpad=12)
# plt.ylabel("Throughput (Gbps)", fontsize=35, labelpad=12);
# ax.tick_params(axis='both', which='major', pad=12)
# ax.tick_params(axis='y', which='major', labelsize=30)
# ax.tick_params(axis='x', which='major', labelsize=30)
# plt.ylim(10, 21)
# plt.ylim(75,100)

fig, ax = plt.subplots(figsize =(9,3), dpi=160)
ax.plot(np.arange(len(df.throughput)), df.throughput, linewidth=1)
# ax.plot(np.arange(len(df.throughput[0:1000])), df.throughput[0:1000], linewidth=2)
# severity_levels = np.arange(5) + 1
ax.grid(True, axis='y', linestyle='--', alpha=0.5 )
ax.set_xlabel('Time (Hours)')
ax_xlim = np.arange(0,len(df.throughput), 60*60*10)
plt.xticks(ax_xlim, [str(int(n/3600)) for n in ax_xlim])

# ax.set_xticks(np.arange(1,6,1))
ax.set_ylabel('Throughput (Gb/s)')
# ax.set_yticks(np.arange(4,22,2))

# inset axes....
axins = ax.inset_axes([0.3, 0.15, 0.35, 0.35])
# axins.imshow(Z2, extent=extent, origin="lower")
# # sub region of the original image
start = 40000
length = 10000
x1, x2, y1, y2 = start, start + length, 7, 21

axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
axins.plot(np.arange(len(df.throughput)), df.throughput)
axins.set_yticks(np.arange(10,25,5))
axins.set_xticks([])
# axins_xlim = np.arange(start,start + length + 3600, 60*60*1.5)
# axins.set_xticks(axins_xlim, [str(int(n/3600)) for n in axins_xlim])
# axins.set_xticks(np.arange(start,start + length+1,500))
axins.grid(True, axis='y', linestyle='--', alpha=0.5 )
# axins.axes.xaxis.set_visible(False)
# axins.set_xticklabels([])
# axins.set_yticklabels([])
#
ax.indicate_inset_zoom(axins, edgecolor="black")
# plt.legend(fontsize = 14, loc='lower left')
plt.savefig('throughput_cc16.pdf', bbox_inches='tight')
